# %%
library(markovchain)

# %%
weatherStates <- c("sunny", "cloudy", "rain")
byRow <- TRUE
weatherMatrix <- matrix(data = c(0.70, 0.2, 0.1,
                                 0.3, 0.4, 0.3,
                                 0.2, 0.45, 0.35), 
                        byrow = byRow, nrow = 3,
                        dimnames = list(weatherStates, weatherStates))
mcWeather <- new("markovchain", states = weatherStates, byrow = byRow,
transitionMatrix = weatherMatrix, name = "Weather")

# %%
mcWeather
# Out:
# Weather
#  A  3 - dimensional discrete Markov Chain with following states
#  sunny cloudy rain
#  The transition matrix   (by rows)  is defined as follows
#        sunny cloudy rain
# sunny    0.7   0.20 0.10
# cloudy   0.3   0.40 0.30
# rain     0.2   0.45 0.35

# %%
plot(mcWeather)
# Out:
# Plot with title “”

# %%
r <- read.csv('1-gram_shakespeare_transition_matrix.csv',row.names='X')

# %%
head(r)
# Out:
#            a            b           c           d          e           f
# a 0.00000000 0.0073313783 0.024926686 0.026881720 0.00000000 0.003421310
# b 0.03421053 0.0052631579 0.000000000 0.002631579 0.35526316 0.000000000
# c 0.10655738 0.0000000000 0.006147541 0.000000000 0.21311475 0.000000000
# d 0.02946768 0.0009505703 0.000000000 0.008555133 0.13783270 0.002851711
# e 0.06279904 0.0005980861 0.007177033 0.027811005 0.04276316 0.009270335
# f 0.15026834 0.0000000000 0.000000000 0.000000000 0.08407871 0.023255814
#             g            h          i           j           k           l
# a 0.014662757 0.0004887586 0.05180841 0.000000000 0.033235582 0.064027370
# b 0.002631579 0.0000000000 0.02368421 0.002631579 0.000000000 0.063157895
# c 0.000000000 0.2274590164 0.02663934 0.000000000 0.075819672 0.010245902
# d 0.002851711 0.0009505703 0.07034221 0.000000000 0.000000000 0.007604563
# e 0.004784689 0.0023923445 0.01525120 0.000000000 0.002093301 0.040071770
# ...

# %%
names(r)
# Out:
#  [1] "a"   "b"   "c"   "d"   "e"   "f"   "g"   "h"   "i"   "j"   "k"   "l"
# [13] "m"   "n"   "o"   "p"   "q"   "r"   "s"   "t"   "u"   "v"   "w"   "x"
# [25] "y"   "z"   "X.1"

# %%
l<-matrix(r)

# %%
mcShake <- new("markovchain", states = k, byrow = byRow,
transitionMatrix = l, name = "Shakespeare")
# Out:
# Error in `colnames<-`(`*tmp*`, value = c("a", "b", "c", "d", "e", "f", : length of 'dimnames' [2] not equal to array extent

# %%
length(l)
# Out:
# [1] 27

# %%
length(names(r))
# Out:
# [1] 27

# %%
k = c(names(r))

# %%
size(matrix)
# Out:
# Error in eval(expr, envir, enclos): could not find function "size"
